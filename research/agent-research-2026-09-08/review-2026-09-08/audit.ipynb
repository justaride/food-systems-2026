# %% [markdown]
# # A1–A6: strukturell kontroll og FAO-reproduksjon
# Kjør fra denne mappen. audit.py leser originalene uten å endre dem. Resultater skrives til review-mappen. Skriptet er kjørt i kontrollen; denne notebooken er en kjørbar inngang til samme kontroll. Primærnedlastingen er registrert separat i primary-captures.json.

# %%
from pathlib import Path
import runpy
assert Path("audit.py").exists(), "Åpne notebooken med review-mappen som arbeidsmappe"
runpy.run_path("audit.py", run_name="__main__");
